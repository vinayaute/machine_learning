# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\User\\3RI technology\\Data Science\\Iris\\Notebook'

# %%
os.path.join(os.getcwd(),"test")
# Out:
# 'C:\\Users\\User\\3RI technology\\Data Science\\Iris\\Notebook\\test'

# %%
cwd=os.getcwd()
print(cwd)
# Out:
# C:\Users\User\3RI technology\Data Science\Iris\Notebook

# %%
os.path.exists(cwd)
# Out:
# True

# %%
#directory path
os.path.dirname(cwd)
# Out:
# 'C:\\Users\\User\\3RI technology\\Data Science\\Iris'

# %%
os.mkdir(" ../test")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8296/2348518265.py in <module>
# ----> 1 os.mkdir(" ../test")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: ' ../test'

# %%
import pandas as pd

# %%
path = "../data/iris.dataset.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
path = "../data/iris.dataset.csv"
df = pd.read_csv(path)
df.head(15)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
df.head(15)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.tail(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df["SepalLengthCm"]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
df["SepalLengthCm"].head()
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: SepalLengthCm, dtype: float64

# %%
df.SepalLengthCm
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\3ri\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\envs\3ri\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\3ri\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df['SepalLengthCm'].tolist()
# Out:
# [5.1,
#  4.9,
#  4.7,
#  4.6,
#  5.0,
#  5.4,
#  4.6,
#  5.0,
#  4.4,
#  4.9,
#  5.4,
#  4.8,
#  4.8,
#  4.3,
#  5.8,
#  5.7,
#  5.4,
#  5.1,
#  5.7,
#  5.1,
#  5.4,
#  5.1,
#  4.6,
#  5.1,
#  4.8,
#  5.0,
#  5.0,
#  5.2,
#  5.2,
#  4.7,
#  4.8,
#  5.4,
#  5.2,
#  5.5,
#  4.9,
#  5.0,
#  5.5,
#  4.9,
#  4.4,
#  5.1,
#  5.0,
#  4.5,
#  4.4,
#  5.0,
#  5.1,
#  4.8,
#  5.1,
#  4.6,
#  5.3,
#  5.0,
#  7.0,
#  6.4,
#  6.9,
#  5.5,
#  6.5,
#  5.7,
#  6.3,
#  4.9,
#  6.6,
#  5.2,
#  5.0,
#  5.9,
#  6.0,
#  6.1,
#  5.6,
#  6.7,
#  5.6,
#  5.8,
#  6.2,
#  5.6,
#  5.9,
#  6.1,
#  6.3,
#  6.1,
#  6.4,
#  6.6,
#  6.8,
#  6.7,
#  6.0,
#  5.7,
#  5.5,
#  5.5,
#  5.8,
#  6.0,
#  5.4,
#  6.0,
#  6.7,
#  6.3,
#  5.6,
#  5.5,
#  5.5,
#  6.1,
#  5.8,
#  5.0,
#  5.6,
#  5.7,
#  5.7,
#  6.2,
#  5.1,
#  5.7,
#  6.3,
#  5.8,
#  7.1,
#  6.3,
#  6.5,
#  7.6,
#  4.9,
#  7.3,
#  6.7,
#  7.2,
#  6.5,
#  6.4,
#  6.8,
#  5.7,
#  5.8,
#  6.4,
#  6.5,
#  7.7,
#  7.7,
#  6.0,
#  6.9,
#  5.6,
#  7.7,
#  6.3,
#  6.7,
# ...

# %%
import re
help(re)
# Out:
# Help on module re:
#
# NAME
#     re - Support for regular expressions (RE).
#
# MODULE REFERENCE
#     https://docs.python.org/3.7/library/re
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This module provides regular expression matching operations similar to
#     those found in Perl.  It supports both 8-bit and Unicode strings; both
#     the pattern and the strings being processed can contain null bytes and
#     characters outside the US ASCII range.
#
#     Regular expressions can contain both special and ordinary characters.
#     Most ordinary characters, like "A", "a", or "0", are the simplest
#     regular expressions; they simply match themselves.  You can
# ...

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df[3:10][["SepalLengthCm","SepalWidthCm"]]
# Out:
#    SepalLengthCm  SepalWidthCm
# 3            4.6           3.1
# 4            5.0           3.6
# 5            5.4           3.9
# 6            4.6           3.4
# 7            5.0           3.4
# 8            4.4           2.9
# 9            4.9           3.1

# %%
df[["SepalLengthCm","SepalWidthCm"]][3:10]
# Out:
#    SepalLengthCm  SepalWidthCm
# 3            4.6           3.1
# 4            5.0           3.6
# 5            5.4           3.9
# 6            4.6           3.4
# 7            5.0           3.4
# 8            4.4           2.9
# 9            4.9           3.1

# %%
df2 = df[["SepalLengthCm","SepalWidthCm"]]
df2
# Out:
#      SepalLengthCm  SepalWidthCm
# 0              5.1           3.5
# 1              4.9           3.0
# 2              4.7           3.2
# 3              4.6           3.1
# 4              5.0           3.6
# ..             ...           ...
# 145            6.7           3.0
# 146            6.3           2.5
# 147            6.5           3.0
# 148            6.2           3.4
# 149            5.9           3.0
#
# [150 rows x 2 columns]

# %%
df[72:78]["PetalLengthCm"]
# Out:
# 72    4.9
# 73    4.7
# 74    4.3
# 75    4.4
# 76    4.8
# 77    5.0
# Name: PetalLengthCm, dtype: float64

# %%
df[72:78].PetalLengthCm
# Out:
# 72    4.9
# 73    4.7
# 74    4.3
# 75    4.4
# 76    4.8
# 77    5.0
# Name: PetalLengthCm, dtype: float64

# %%
df[72:78][["PetalLengthCm","SepalWidthCm"]].mean()
# Out:
# PetalLengthCm    4.683333
# SepalWidthCm     2.833333
# dtype: float64

# %%
sl_45 = df[45:48][["SepalLengthCm"]]
sl_45
# Out:
#     SepalLengthCm
# 45            4.8
# 46            5.1
# 47            4.6

# %%
sl_45.values
# Out:
# array([[4.8],
#        [5.1],
#        [4.6]])

# %%
sl_45.values[0]
# Out:
# array([4.8])

# %%
sl_45.values[0][0]
# Out:
# 4.8

# %% [markdown]
# #CONDITION in DATAFRAME

# %%
#slicing wrt condition
# sl >= 5
df_sl_5 = df[df["SepalLengthCm"] >= 5.0]
df_sl_5
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 7      8            5.0           3.4            1.5           0.2
# 10    11            5.4           3.7            1.5           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# 7       Iris-setosa
# 10      Iris-setosa
# ..              ...
# ...

# %%
df["SepalLengthCm"][df["SepalLengthCm"] >= 5]
# Out:
# 0      5.1
# 4      5.0
# 5      5.4
# 7      5.0
# 10     5.4
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 128, dtype: float64

# %%
df[(df["SepalLengthCm"] >= 5) & (df["PetalLengthCm"] >= 5)]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 77    78            6.7           3.0            5.0           1.7
# 83    84            6.0           2.7            5.1           1.6
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
# 111  112            6.4           2.7            5.3           1.9
# ...

# %%
df[(df["SepalWidthCm"] >= 3.6) & (df["Species"] != "Iris-setosa")]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 109  110            7.2           3.6            6.1           2.5
# 117  118            7.7           3.8            6.7           2.2
# 131  132            7.9           3.8            6.4           2.0
#
#             Species
# 109  Iris-virginica
# 117  Iris-virginica
# 131  Iris-virginica

# %% [markdown]
# #INDEXING DATAFRAME

# %%
# .loc (hybrid) -> (number and name dono chalega)  loc = location
# .iloc  (row no.,  col no.)

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.iloc[3,2]          #3rd row   2nd column
# Out:
# 3.1

# %%
df.iloc[3:6, 2: ]
# Out:
#    SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 3           3.1            1.5           0.2  Iris-setosa
# 4           3.6            1.4           0.2  Iris-setosa
# 5           3.9            1.7           0.4  Iris-setosa

# %%
df.iloc[[2,5,7,8], [0,3]]
# Out:
#    Id  PetalLengthCm
# 2   3            1.3
# 5   6            1.7
# 7   8            1.5
# 8   9            1.4

# %%
df.iloc[[2,5],[3,3]]
# Out:
#    PetalLengthCm  PetalLengthCm
# 2            1.3            1.3
# 5            1.7            1.7

# %%
df.loc[4, 'PetalLengthCm']
# Out:
# 1.4

# %%
df.loc[4, 'PetalWidthCm']
# Out:
# 0.2

# %% [markdown]
# #Group-by

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
g = df.groupby("Species")
g.head()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 50    51            7.0           3.2            4.7           1.4
# 51    52            6.4           3.2            4.5           1.5
# 52    53            6.9           3.1            4.9           1.5
# 53    54            5.5           2.3            4.0           1.3
# 54    55            6.5           2.8            4.6           1.5
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# ...

# %%
#syntax of group by
# .groupby(by, axis, level, as_index, sort, group_keys, squeeze)
